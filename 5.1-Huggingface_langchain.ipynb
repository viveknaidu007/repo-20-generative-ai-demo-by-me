# %%
import os

mykey = os.getenv("apikey")

# %%
#now im going to perform the hugging face model without paying any money

# %%
#before doing projects on hugging face we have to install this

# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# Out:
# ...
#    ---------------------------------------- 0.0/105.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/105.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/105.0 MB 660.6 kB/s eta 0:02:39
#    ---------------------------------------- 0.1/105.0 MB 751.6 kB/s eta 0:02:20
#    ---------------------------------------- 0.2/105.0 MB 1.0 MB/s eta 0:01:43
#    ---------------------------------------- 0.2/105.0 MB 1.3 MB/s eta 0:01:24
#    ---------------------------------------- 0.2/105.0 MB 1.3 MB/s eta 0:01:24
#    ---------------------------------------- 0.5/105.0 MB 1.8 MB/s eta 0:00:59
#    ---------------------------------------- 0.5/105.0 MB 1.5 MB/s eta 0:01:09
#    ---------------------------------------- 0.7/105.0 MB 1.7 MB/s eta 0:01:02
#    ---------------------------------------- 0.9/105.0 MB 1.9 MB/s eta 0:00:55
#    ---------------------------------------- 1.0/105.0 MB 2.0 MB/s eta 0:00:53
# ...

# %%
#step2: import all librarires
#langchian is wrapper on different different api not even openai we can access many api by using this langchain many open source model and all it has been designed in such a way.
from langchain import PromptTemplate, HuggingFaceHub, LLMChain

# %%
#step: setting the environment
import os
#os.getenv("yourkey")
os.environ['HUGGINGFACEHUB_API_TOKEN'] = "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"

# %% [markdown]
# TEXTTEXT GENERATION MODELS | SeqSeq Models | Encoder=Decoder

# %%
prompt = PromptTemplate(
    input_variables=["product"],
    template="what is a good name for a company that makes {product}"
)

# %% [markdown]
# llm = HuggingFaceHub(repo_id='google/flan-t5-large', model_kwargs={'temperature':0})

# %%
chain = LLMChain(llm=HuggingFaceHub(repo_id='google/flan-t5-large', model_kwargs={'temperature':0}),prompt = prompt)
# Out:
# c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'InferenceApi' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '1.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)

# %%
chain.run("camera")
# Out:
# c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# 'Canon'

# %%
chain.run("watch")
# Out:
# 'Rolex'

# %%
chain.run("colorful cloths")
# Out:
# 'Colorful'

# %%
#we can do any model lets use facemodel
#we can copy in this below link in this model : https://huggingface.co/facebook/mbart-large-50
#facebook/mbart-large-50

# %%
chain2 = LLMChain(llm=HuggingFaceHub(repo_id='facebook/mbart-large-50', model_kwargs={'temperature':0}),prompt = prompt)
# Out:
# c:\Users\poppo\anaconda3\envs\mlproj\lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'InferenceApi' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '1.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)

# %%
chain2.run("Mobile")
#oh lol ,its just returning the prompt
# Out:
# 'what is a good name for a company that makes Mobile'

# %%
#now

# %% [markdown]
# Text Generation Models | Decoder only Models in next 5.2
